# %% [markdown]
# ### 1 . What is Flask framework and its Advantages ?

# %% [markdown]
# ##### Flask :
# - flask is a micro web framework written in python. it is classsified as mircroweb framework, because it does not require any tool or libraries. it has no database abstraction layer, form validation, or any other components where pre-existing third party libraries pprovide common functions.
#
# - it is designed to create and scale web apps quickly an simply.

# %% [markdown]
# ##### Advantages of Flask :
#
# 1. It is a lightweight framework that offers hassle free development.
# 2. Provides flexibility to developers to experiment with thier modules or architecture.
# 3. It is suitable for small projects .
# 4. Offers a built in development server and fast debugger.
# 5. Easily scalable for applications.
# 6. Support for secure cookies

# %% [markdown]
# ### 2 . Create Flask app to show "Hello world!" with Output screenshot

# %% [markdown]
# Flask code :

# %% [markdown]
# ![Flask_code_Screenshot.jpg](attachment:e76579f7-0ffa-4afc-b1d3-12b1dba86654.jpg)

# %% [markdown]
# Flask code output showing "Hello World!"

# %% [markdown]
# ![Flask_code_output.png](attachment:224fcebc-b95d-4c05-9215-2eaf7c0745a8.png)

# %% [markdown]
# ### 3 . What is app routing in Flask ? why do we use it ?

# %% [markdown]
# ##### App routing :
#
# - App routing means mapping URL to a specific function that will handle the logic for that URL. Thre latest framework use the routing technique to help users remember application URL.

# %% [markdown]
# ##### Why do we use App routing :
# - The route () decorator in flask is used to bind URL to a function. as a result when a URL is mentioned in the browser, the function is executed to give the result.

# %% [markdown]
# ### 4 . Create a "/welcome" and "/" to show given messages

# %% [markdown]
# Flask Code to create messages under routing :

# %% [markdown]
# ![Flask_welcome_assignment.jpg](attachment:c3f98c80-b3e2-4657-9917-5f56c3ccf3bd.jpg)

# %% [markdown]
# Output 1 - showing default page with details :

# %% [markdown]
# ![Flask_output_default.jpg](attachment:59ec5dfa-53b6-48b9-97ae-3d67b203aa1c.jpg)

# %% [markdown]
# Output 2 - Showing welcome url and its message :

# %% [markdown]
# ![Flask_output_welcome.jpg](attachment:27639c58-c228-4178-a4d1-ea7da3abb467.jpg)

# %% [markdown]
# ### 5 . What function is used in Flask for URL building ? demonstrate url_for () function

# %% [markdown]
# -  The url_for () function is used to build URL to specific function dynamically. the first argument is the name of the specified function, anf then we can pass any number of keywords as arguments corresponding to the variable part of the uRL.

# %% [markdown]
# ##### Demonstrating url_for () function : following is code in flask

# %% [markdown]
# ![Flask_assignment_url_code (2).jpg](attachment:e544712e-47b9-4c45-ac6c-b1cd6884e29e.jpg)

# %% [markdown]
# Output 1 as admin :

# %% [markdown]
# ![Flask_assignment_url_admin.jpg](attachment:81ce5983-8c69-448e-b858-b58c61f1efa6.jpg)

# %% [markdown]
# Output 2 as guest user :

# %% [markdown]
# ![Flask_assignment_url_guest.jpg](attachment:0a05bed8-3297-47ba-a0fb-8e3bb16a6f58.jpg)
